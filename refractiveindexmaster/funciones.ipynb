# %% [markdown]
# # Funciones para calcular los índices de refracción como función de las longitudes de onda

# %%
import numpy as np

# %%
def formula1(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    n_2 = 1 + C1 + (C2*long**2)/(long**2-C3**2) + (C4*long**2)/(long**2-C5**2) + (C6*long**2)/(long**2-C7**2) + (C8*long**2)/(long**2-C9**2) + (C10*long**2)/(long**2-C11**2) + (C12*long**2)/(long**2-C13**2) + (C14*long**2)/(long**2-C15**2) + (C16*long**2)/(long**2-C17**2)
    result = np.sqrt(n_2)

# %%
def formula2(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    n_2 = 1 + C1 + (C2*long**2)/(long**2-C3) + (C4*long**2)/(long**2-C5) + (C6*long**2)/(long**2-C7) + (C8*long**2)/(long**2-C9) + (C10*long**2)/(long**2-C11) + (C12*long**2)/(long**2-C13) + (C14*long**2)/(long**2-C15) + (C16*long**2)/(long**2-C17)
    result = np.sqrt(n_2)

# %%
def formula3(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    n_2 = C1 + C2*long**(C3) + C4*long**(C5) + C6*long**(C7) + C8*long**(C9) + C10*long**(C11) + C12*long**(C13) + C14*long**(C15) + C16*long**(C17)
    result = np.sqrt(n_2)

# %%
def formula4(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    n_2 = C1 + (C2*long**C3)/(long**2-C4**C5) + (C6*long**C7)/(long**2-C8**C9) + C10*long**C11 + C12*long**C13 + C14*long**C15 + C16*long**C17
    result = np.sqrt(n_2)

# %%
def formula5(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    result = C1 + C2*long**C3 + C4*long**C5 + C6*long**C7 + C8*long**C9 + C10*long**C11

# %%
def formula6(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    result = 1 + C1 + C2/(C3-long**(-2.0)) + C4/(C5-long**(-2.0)) + C6/(C7-long**(-2.0)) + C8/(C9-long**(-2.0)) + C10/(C11-long**(-2.0))

# %%
def formula7(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    result = C1 + C2/(long**2.0 - 0.028) + C3*(1.0/(long**2.0 - 0.028))**2.0 + C4*long**2.0 + C5*long**4.0 + C6*long**6.0

# %%
def formula8(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    patata = C1 + (C2*long**2.0)/(long**2.0 - C3) + C4*long**2.0
    n_2 = (2.0*patata + 1)/(1 - patata)
    result = np.sqrt(n_2)

# %%
def formula9(*coefs,long):
    C1 = 0
    C2 = 0
    C3 = 0
    C4 = 0
    C5 = 0
    C6 = 0
    C7 = 0
    C8 = 0
    C9 = 0
    C10 = 0
    C11 = 0
    C12 = 0
    C13 = 0
    C14 = 0
    C15 = 0
    C16 = 0
    C17 = 0
    n_2 = C1 + C2/(long**2.0 - C3) + (C4*(long - C5))/((long - C5)**2.0 + C6)
    result = np.sqrt(n_2)
