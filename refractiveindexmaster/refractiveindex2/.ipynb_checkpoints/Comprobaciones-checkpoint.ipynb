# %% [markdown]
# from refractivesqlite import dboperations as DB
#
# dbpath = "refractive.db"
# db = DB.Database(dbpath)
# db.create_database_from_url()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from refractivesqlite import dboperations as DB

dbpath = "refractive.db"
db = DB.Database(dbpath)
# Out:
# Database file found at refractive.db

# %%
list_of_pages = db.search_pages()

print(list_of_pages[0])
# Out:
# (0, 'main', 'Ag', 'Johnson', 'main\\Ag\\Johnson.yml', 1, 1, 0.1879, 1.937, 49)

# %%
len(db.get_material_n_numpy(5))
# Out:
# Material main\Ag\Werner.yml loaded.
# 150

# %%
#db.get_material_n_numpy(5)
import matplotlib.pyplot as plt

plt.plot(db.get_material_n_numpy(5))
# Out:
# Material main\Ag\Werner.yml loaded.
# ...

# %%
db.get_all_shelfs()
# Out:
# ['main', 'organic', 'glass', 'other', '3d']

# %%
db.search_custom('select * from pages where shelf="glass"')
# Out:
# 1708 results found.
# [(805,
#   'glass',
#   'BK7',
#   'SCHOTT',
#   'glass\\schott\\N-BK7.yml',
#   1,
#   1,
#   0.3,
#   2.5,
#   25),
#  (806,
#   'glass',
#   'BK7',
#   'OHARA',
#   'glass\\ohara\\S-BSL7.yml',
#   1,
#   1,
#   0.29,
#   2.4,
#   31),
#  (807,
#   'glass',
#   'BK7',
#   'HIKARI',
#   'glass\\hikari\\J-BK7A.yml',
#   1,
#   1,
#   0.365015,
#   2.05809,
#   33),
#  (808,
#   'glass',
#   'BK7',
#   'CDGM',
#   'glass\\cdgm\\H-K9L.yml',
#   1,
#   1,
#   0.365,
#   1.711,
#   34),
#  (809,
#   'glass',
#   'BK7',
#   'HOYA',
#   'glass\\hoya\\BSC7.yml',
#   1,
#   1,
#   0.36501,
#   1.01398,
#   38),
#  (810,
#   'glass',
#   'BK7',
#   'SUMITA',
#   'glass\\sumita\\K-BK7.yml',
#   1,
#   1,
#   0.36,
#   1.55,
#   25),
#  (811, 'glass', 'BK7', 'LZOS', 'glass\\lzos\\K8.yml', 1, 0, 0.365, 2.3254, 31),
#  (812,
#   'glass',
#   'BAF10',
#   'SCHOTT',
#   'glass\\schott\\N-BAF10.yml',
#   1,
#   1,
#   0.35,
#   2.5,
#   21),
#  (813,
#   'glass',
#   'BAF10',
# ...
